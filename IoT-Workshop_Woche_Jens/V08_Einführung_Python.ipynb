# %%
name = input("Wie ist dein Name?")
print("Hallo ",name)
# Out:
# Wie ist dein Name?jens
# Hallo  jens

# %%
#Datentypen

"""
myNum = 2
print(type(myNum))
myStr = input("Wie lautet deine Lieblingszahl? ")
myNum = int(myStr)

print("Deine Lieblingszahl ist also: " + str(myNum))
"""

#myFloat = 12.34

#print("Der Datentyp der Zahl ist " + str(type(myFloat)))

#Liste erzeugen
myList = ['1',2]

#Element an Liste anhängen
myList.append(4)


#komplette Liste ausgeben
print("Die gesamte Liste lautet " + str(myList))

#Element der Liste an bestimmter Stelle hinzufügen insert(Position,Wert)
myList.insert(2,3)

#Element entfernen remove(Position, Wert)
#myList.remove(4)

#Listenelemente einzeln ausgeben
for i in myList:
    
    myResult = int(i)*3
    
    if myResult % 2 != 0:
        print(myResult)
        
#zuletzt hinzugefügtes Element aus Liste
#myElement = myList.pop()

#print(myElement)
# Out:
# Die gesamte Liste lautet ['1', 2, 4]
# 3
# 9

# %%
#Split

name = input("Wie ist dein Name?")
myStr = "Ich lerne gerade python"
myList = myStr.split(" ")

myList[0] = name
myList[1] = "lernt"
print(myList)

"""Zusammenfügen der Listenelemente via for-Schleife"""
"""
for i in myList:
    myStr = myStr +" " + str(i)

print(myStr)
"""

# Liste wird ersetzt durch ein "durchlaufbares" Objekt mit einem Index
# k = key; v = value
for k, v in enumerate(myList):
    print(k, v)
# Out:
# Wie ist dein Name?Jens
# ['Jens', 'lernt', 'gerade', 'python']
# 0 Jens
# 1 lernt
# 2 gerade
# 3 python

# %%
#zahl = input("Bitte Euro eingeben " + )

#für beliebigen Geldbetrag kleinst möglichen Geldbetrag zurückgeben

amountStr = input("Nennen sie den Betrag ")
amountList = amountStr.split(",")
amount = int(amountList[0])*100 + int(amountList[1])

#print(amountList)
#print(amount)


coins = [200, 100, 50, 20, 10, 5, 2, 1]

denominations =[]

for k, v in enumerate(coins):
    rest = amount % v
    amount = amount - rest
    denominations.append(int(amount/v))
    amount = rest

    
#print(denominations)

"""
print(str(denominations[0]) + " 2-Euro Münzen")
print(str(denominations[1]) + " 1-Euro Münzen")
print(str(denominations[2]) + " 50-Cent Münzen")
print(str(denominations[3]) + " 20-Cent Münzen")
print(str(denominations[4]) + " 10-Cent Münzen")
print(str(denominations[5]) + " 5-Cent Münzen")
print(str(denominations[6]) + " 2-Cent Münzen")
print(str(denominations[7]) + " 1-Cent Münzen")
"""
print()
print("Ausgabe mit der geringsten Anzahl an Münzen: ")
print()

for k,v in enumerate(denominations):
    if v > 0:
        if k <3 :
            print(str(v) + " " + str(int(coins[k]/100)) + "-Euro Münzen")
        else:
            print(str(v) + " " + str(coins[k]) + "-Cent Münzen")

# %%
#zahl = input("Bitte Euro eingeben " + )

#für beliebigen Geldbetrag kleinst möglichen Geldbetrag zurückgeben

amountStr = input("Nennen sie den Betrag ")
amountList = amountStr.split(",")
amount = int(amountList[0])*100 + int(amountList[1])

#print(amountList)
#print(amount)


coins = [200, 100, 50, 20, 10, 5, 2, 1]

denominations =[]

for k, v in enumerate(coins):
    rest = amount % v
    amount = amount - rest
    denominations.append(int(amount/v))
    amount = rest

    
#print(denominations)

"""
print(str(denominations[0]) + " 2-Euro Münzen")
print(str(denominations[1]) + " 1-Euro Münzen")
print(str(denominations[2]) + " 50-Cent Münzen")
print(str(denominations[3]) + " 20-Cent Münzen")
print(str(denominations[4]) + " 10-Cent Münzen")
print(str(denominations[5]) + " 5-Cent Münzen")
print(str(denominations[6]) + " 2-Cent Münzen")
print(str(denominations[7]) + " 1-Cent Münzen")
"""
print()
print("Ausgabe mit der geringsten Anzahl an Münzen: ")
print()

for k,v in enumerate(denominations):
    if v > 0:
        if k <3 :
            print(str(v) + " " + str(int(coins[k]/100)) + "-Euro Münzen")
        else:
            print(str(v) + " " + str(coins[k]) + "-Cent Münzen")
# Out:
# Nennen sie den Betrag 3,45
#
# Ausgabe mit der geringsten Anzahl an Münzen:
#
# 1 2-Euro Münzen
# 1 1-Euro Münzen
# 2 20-Cent Münzen
# 1 5-Cent Münzen

# %%
import pandas as pd
S = pd.Series([11, 28, 72, 3, 5, 8])
print(S)
# Out:
# 0    11
# 1    28
# 2    72
# 3     3
# 4     5
# 5     8
# dtype: int64

# %%
sideL = float(input("Bitte geben Sie die Seitenlänge in cm an "))

flaeche = sideL * sideL

print("Die Fläche des Rechtecks beträgt "+ str(flaeche) + "cm^2")
# Out:
# Bitte geben Sie die Seitenlänge in cm an 3
# Die Fläche des Rechtecks beträgt 9.0cm^2

# %%
import pandas as pd

df = pd.read_csv("C:/Users/Workshop/Desktop/IoT-Workshop_Woche/ProdTag_12_05_2021.csv", sep = ";")
#print(df.head(2)) #ausgabe nur der ersten beiden Datenzeilen + Spaltenüberschriften

#print(df["Produktvariante"].head(2)) #nur bestimmte Spalte und nur die ersten beiden Datenzeilen ohne Überschrift

#print(df.shape) #Ausgabe der Zeilen und Spaltenanzahl

#print(df[["Produktvariante", "Prozessbeschreibung"]].head(2)) #Zwei bestimmte Spalten und nur die ersten beiden Datenzeilen

#print(df[df["Produktvariante"] == 8010]) #Ausgabe aller Daten der Produktvariante 8010

#print(df["Produktvariante"] == 8010) #Gibt aus für welche Zeilen das Argument true/false ist



headers = df.columns.tolist()


#for header in headers:
 #   print(df[df[header].isna()])


#print(headerList)
#df = df.drop('Produktvariante', axis = 1)


#df.at[1, 'Produktvariante'] =None
#df.at[112, 'Produktvariante'] =None


    
#df[df.isna().any(axis=1)]
#df.info()

#df["Transportzeit"].unique()

df.head(20)
#df[df["Produktvariante"].isna()] #filtern nach NaN Werten und ganze Tabelle augeben




#df
# Out:
#     Produktvariante  Prozessschritt  Auftragsnummer  \
# 0              8010              10            1329
# 1              8010              20            1329
# 2              8010              30            1329
# 3              8010              40            1329
# 4              8010              50            1329
# 5              8010              60            1329
# 6              8010              10            1329
# 7              8010              20            1329
# 8              8010              30            1329
# 9              8010              40            1329
# 10             8010              50            1329
# 11             8010              60            1329
# 12             8010              10            1329
# 13             8010              20            1329
# 14             8010              30            1329
# 15             8010              40            1329
# 16             8010              50            1329
# 17             8010              60            1329
# 18             8010              10            1329
# 19             8010              20            1329
#
#                     Prozessbeschreibung  Prozessnummer  Startdatum Startzeit  \
# 0   release a defined part on stopper 1            212  12.05.2021  10:02:25
# 1                feed part from magazin            200  12.05.2021  10:03:07
# 2     assemble a PCB with one fuse left            302  12.05.2021  10:04:45
# 3                feed part from magazin            200  12.05.2021  10:07:27
# 4          pressing for time in seconds            110  12.05.2021  10:07:43
# 5           store a part from stopper 2            211  12.05.2021  10:09:49
# 6   release a defined part on stopper 1            212  12.05.2021  10:02:43
# 7                feed part from magazin            200  12.05.2021  10:03:23
# 8     assemble a PCB with one fuse left            302  12.05.2021  10:06:35
# 9                feed part from magazin            200  12.05.2021  10:09:28
# 10         pressing for time in seconds            110  12.05.2021  10:09:53
# 11          store a part from stopper 2            211  12.05.2021  10:11:51
# 12  release a defined part on stopper 1            212  12.05.2021  10:02:59
# 13               feed part from magazin            200  12.05.2021  10:03:38
# 14    assemble a PCB with one fuse left            302  12.05.2021  10:08:22
# 15               feed part from magazin            200  12.05.2021  10:11:15
# 16         pressing for time in seconds            110  12.05.2021  10:11:36
# 17          store a part from stopper 2            211  12.05.2021  10:13:18
# 18  release a defined part on stopper 1            212  12.05.2021  10:03:15
# 19               feed part from magazin            200  12.05.2021  10:03:55
#
#       Enddatum   Endzeit  Arbeitsstation  Transportzeit
# 0   12.05.2021  10:02:40               5              0
# 1   12.05.2021  10:03:09              11             27
# 2   12.05.2021  10:06:28               8              6
# 3   12.05.2021  10:07:30               6             63
# 4   12.05.2021  10:07:45               7             14
# 5   12.05.2021  10:10:01               5           1126
# 6   12.05.2021  10:02:56               5              0
# 7   12.05.2021  10:03:25              11             27
# 8   12.05.2021  10:08:18               8              6
# 9   12.05.2021  10:09:30               6             63
# 10  12.05.2021  10:09:57               7             14
# 11  12.05.2021  10:12:03               5           1126
# 12  12.05.2021  10:03:11               5              0
# 13  12.05.2021  10:03:41              11             27
# 14  12.05.2021  10:10:05               8              6
# 15  12.05.2021  10:11:18               6             63
# 16  12.05.2021  10:11:43               7             14
# 17  12.05.2021  10:13:30               5           1126
# 18  12.05.2021  10:03:28               5              0
# 19  12.05.2021  10:03:57              11             27

# %%
import pandas as pd

df = pd.read_csv(
    'C:/Users/Workshop/Desktop/IoT-Workshop_Woche/ProdTag_12_05_2021.csv', sep=';')

df = df.reset_index()  # make sure indexes pair with number of rows


idList = [1]

werkstueckID = 1

counter = 1  # zählt die der werkstueckID bisher zugerordneten Zeilen. Wechselt die ID bevor der Counter bei 6 ist, wird für die Zeile 'error' eingetragen

errorCounter = 0

for index, row in df.iterrows():

    if index == 0:

        # falls es sich um die erste Zeile handelt, Inhalte speichern und mit nächster Iteration fortfahren
        lastRowList = [row['Produktvariante'], row['Prozessschritt'], row['Auftragsnummer'], row['Prozessbeschreibung'],
                       row['Prozessnummer'], row['Startdatum'], row['Startzeit'], row['Enddatum'], row['Endzeit'], row['Arbeitsstation'], row['Transportzeit']]
        continue

    if (row['Produktvariante'] == lastRowList[0]) & (row['Prozessschritt'] == lastRowList[1] + 10) & (row['Auftragsnummer'] == lastRowList[2]):

        idList.append(werkstueckID)
        counter += 1

    else:
        if counter < 6:
            for x in range(counter):
                idList[len(idList)-1 - x] = 'error'
                errorCounter+= 1

            # idList.append('error')

        werkstueckID += 1
        idList.append(werkstueckID)
        counter = 1

    lastRowList = [row['Produktvariante'], row['Prozessschritt'], row['Auftragsnummer'], row['Prozessbeschreibung'],
                   row['Prozessnummer'], row['Startdatum'], row['Startzeit'], row['Enddatum'], row['Endzeit'], row['Arbeitsstation'], row['Transportzeit']]

# print(idList)
# print(lastRowList[1])

# print(idList[100])

# Liste mit IDs und error hinzufügen
df['werkstueckID'] = idList

errorIndexList = []
errorPosition = 2

#print("errorCounter hat gezaehlt " + str(errorCounter))

for index, row in df.iterrows():
        if row['werkstueckID'] == 'error':
            errorIndexList.append(errorPosition)
        errorPosition += 1
    

#print(df.loc[df['werkstueckID'] == 'error'].info())

#print(df.loc[df['werkstueckID'] == 'error'])

#dfError = df[df['werkstueckID'] == 'error']

#dfError.to_csv('C:/Users/Workshop/Desktop/IoT-Workshop_Woche/errorList.csv', sep=';')

#df.to_csv('C:/Users/Workshop/Desktop/IoT-Workshop_Woche/ProdError.csv', sep=';')

#df.to_csv('/Users/JensRosenkranz/Downloads/errorList.csv', sep=';')

#dfError

#print(errorIndexList)
#print(len(errorIndexList))

#df.loc[min('Startzeit')]




#höchste ID von DF
# while error exists
#for each schleife iteriert durch alle zeilen des dfError
#WENN counter == 6 dannn counter erhöhen

#WENN bleibe stehen bei erster zeile des Prozesssschritt 10 welche auf error steht und minimaler Startzeit
 #   wenn das zutrifft vergibt die nächst höchste ID; counter erhöhen
#WENN zeile mit Arbeitsschritt 20, die auf error steht mit gleicher Produktvartiante und Auftragsnummer und minimaler startzeit
#... if bedingung für alle Arbeitsschritte ; counter erhöhen
#WENN Arbeitsshritt 60 erreicht und ID vergeben wurde; counter erhöhen"""

#Startzeit zu datetime konvertieren
df['Startzeit']=pd.to_datetime(df['Startzeit'])
dfError['Startzeit']=pd.to_datetime(dfError['Startzeit'])



#Variable iteriert duch alle Arbeitsschritte
PScounter = 10

#for-Schleife sucht Arbeitsschritt 10 mit minimaler Startzeit
#for row in dfError.iterrows():
    
    #falls es sich um den gesuchten Prozesssschritt mit minimaler Startzeit handelt
#    if (row['Prozessschritt'] == PScounter) & (row['werkstueckID'] == 'error'):
        #Arbeitsschritt 10, gültige ID eintragen
    
        #for-Schleife sucht 20,30,40,50,60
#        for row in dfError.iterrow():
            #aktuelle werkstueckID in Zeile werkstueckID eintragen
            #gültige ID eintragen
#       PScounter +=10
    
currentID = 1000

######################
#######ACHTUNG: Nullwerte löschen
#####################


#while error exists
#while ('error' in df.values) | (currentID <= 1002) :
while currentID <= 1002:
    #print("\nThis value exists in Dataframe")
    
    #for-Schleife die jeden der 6 Prozessschritte durchläuft
    for x in range(6):
        #df[(df['Prozessschritt']==20)  & (df['werkstueckID'] == 'error')].nsmallest(1, 'Startzeit')
        getIndex = str(df[(df['Prozessschritt']==(x+1)*10)  & (df['werkstueckID'] == 'error')].nsmallest(1, 'Startzeit').index)
        
        #Ausgabe des Index auf den Integerwert kürzen
        leftstripIndex = getIndex.strip('Int64Index([')
        rightstripIndex = leftstripIndex.strip("], dtype='int64')")
        intIndex = int(rightstripIndex)

        #row des df an der Stelle des Index auf aktuelle ID updaten
        df.at[intIndex, 'werkstueckID'] = currentID  
    currentID+=1

        #df.at[getIndex, 'werkstueckID'] = 1000

print(df[df['werkstueckID'] == 1000])

#####TEST#### Ausgabe eines bestimmten Arbeitsschritts mit kleinster Startzeit
#print(df[(df['Prozessschritt']==30)  & (df['werkstueckID'] == 'error')].nsmallest(1, 'Startzeit'))
#####TEST####

#df.at[df[(df['Prozessschritt']==20)  & (df['werkstueckID'] == 'error')].nsmallest(1, 'Startzeit').index, 'werkstueckID']
        
#für jeden Prozessschritt denjenigen mit minimaler Startzeit suchen und ID eintragen




#dfError[(dfError['Startzeit'].min()) & (dfError['Arbeitsschritt'] == AScounter) 

#dfError.loc[(dfError['Startzeit'].min()) & (dfError['Prozessschritt'] == 20)]



#dfError['Prozessschritt'] == 20

#dfError['Startzeit'].min(axis = 1)


#dfError.loc[dfError['Startzeit'].min()]

#dfError.loc[dfError['Prozessschritt'] == 20]


#nach Arbeitsschritten filtern und in neuem df speichern
#neuen df nach Darum sortieren und aufsteigend durchnummerieren (beginnend mit höchster ID aus orginal df)
#das mit jedem Arbeitsschritt durchführen
#

#dfNew = dfError[dfError['Prozessschritt'] == 10]

#idCounter = 1000

#for i,row in dfNew.iterrows():
#    dfNew.ix[i]['werkstueckID'] = idCounter
#    idCounter +=1
    
#    row['werkstueckID'] = idCounter
#    idCounter +=1

#dfNew
# Out:
#      index  Produktvariante  Prozessschritt  Auftragsnummer  \
# 72      72             8011              10            1330
# 73      73             8011              20            1330
# 167    167             8011              40            1330
# 168    168             8011              50            1330
# 169    169             8011              60            1330
#
#                      Prozessbeschreibung  Prozessnummer  Startdatum  \
# 72   release a defined part on stopper 1            212  12.05.2021
# 73                feed part from magazin            200  12.05.2021
# 167               feed part from magazin            200  12.05.2021
# 168         pressing for time in seconds            110  12.05.2021
# 169          store a part from stopper 2            211  12.05.2021
#
#               Startzeit    Enddatum   Endzeit  Arbeitsstation  Transportzeit  \
# 72  2022-09-21 10:19:11  12.05.2021  10:19:26               5              0
# 73  2022-09-21 10:19:53  12.05.2021  10:19:55              11             27
# 167 2022-09-21 10:29:48  12.05.2021  10:29:50               6             63
# 168 2022-09-21 10:30:08  12.05.2021  10:30:10               7             14
# 169 2022-09-21 10:32:10  12.05.2021  10:32:22               5           1126
#
#     werkstueckID
# 72          1000
# 73          1000
# 167         1000
# 168         1000
# 169         1000

# %%
import pandas as pd

df = pd.read_csv(
    'C:/Users/Workshop/Desktop/IoT-Workshop_Woche/ProdWID_NoNan_ID_Zeiten.csv', sep=';')

df
